# %% [markdown]
# # journalists scraper

# %% [markdown]
# ## Load Libraries

# %%
# Selenium
import selenium
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
# Reqeusts
import requests
# Other tools
from bs4 import BeautifulSoup
from datetime import datetime
from datetime import timedelta
from datetime import date
import csv
import pandas as pd
import time
import json
import fnmatch
import os
import tabula
from tabula.io import read_pdf

# %% [markdown]
# ## Functions

# %%
def requests_get_item(url, item):
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36"}
    if item == "html":       
        page = requests.get(url, headers = headers)
        soup = BeautifulSoup(page.text, 'html.parser')
        return(soup)
    
    elif item == "pdf":
        page = requests.get(url, headers = headers, stream=True)
        return(page)
    else:
        print("Valid Item Not Selected")

def download_pdfs(ls_pdf_urls, download_path, file_name):
    counter = 0 
    for pdf_url in ls_pdf_urls:
        counter = counter +1
        g = requests_get_item(pdf_url, "pdf")
        with open(f'{download_path}{file_name}_{counter}.pdf', 'wb') as sav:
            for chunk in g.iter_content(chunk_size=1000000):
                sav.write(chunk)
        print(f"download number: {counter}")
                
                
def convert_pdf_to_csv(pdf_directory, csv_directory):
    directory = fr'{pdf_directory}'
    directory_output = fr'{csv_directory}'
    count = 0
    for file in os.listdir(directory):        
        if file.endswith(".pdf"):
            count = count + 1 
            print(f'{directory}{file}: Conversion {count}')
            tabula.convert_into(f'{directory}{file}', f'{directory_output}{count}.csv', output_format="csv", pages='all')

# %% [markdown]
# ## Functions Using Selenium

# %%
# Define important paths
executable_path = "https://www.migrationpolicy.org/data/state-profiles/state/demographics/MD"
download_path = f"test"

# Define Routes (usually in xpaths)

def browser_instance(executable_path, headless, download_path):
    
    
    chrome_options =  Options()
    if headless:
        chrome_options.add_argument("--headless")   
    chrome_options.add_experimental_option("prefs", {
            "download.default_directory": download_path})    
    driver = webdriver.Chrome(executable_path=executable_path, options = chrome_options)
    return driver  

def signIn(driver, url, signin_field, username_field, password_field):  
    driver.get(url)
    sign_in = driver.find_element_by_xpath(signin_field)
    sign_in.click()
    email_field = driver.find_element_by_xpath(username_field)
    password_field = driver.find_element_by_xpath(password_field)
    email_field.send_keys(USERNAME)
    password_field.send_keys(PASSWORD + Keys.RETURN)

# %%
driver = browser_instance(executable_path, False, download_path)
driver.get("https://www.migrationpolicy.org/data/state-profiles/state/demographics/MD")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/common/service.py in start(self)
#      71             cmd.extend(self.command_line_args())
# ---> 72             self.process = subprocess.Popen(cmd, env=self.env,
#      73                                             close_fds=platform.system() != 'Windows',
#
# /opt/homebrew/Cellar/python@3.9/3.9.7_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     950
# --> 951             self._execute_child(args, executable, preexec_fn, close_fds,
#     952                                 pass_fds, cwd, env,
#
# /opt/homebrew/Cellar/python@3.9/3.9.7_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1820                         err_msg = os.strerror(errno_num)
# -> 1821                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1822                 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'https://www.migrationpolicy.org/data/state-profiles/state/demographics/MD'
#
# During handling of the above exception, another exception occurred:
#
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-8-25347176ba5f> in <module>
# ----> 1 driver = browser_instance(executable_path, False, download_path)
#       2 driver.get("https://www.migrationpolicy.org/data/state-profiles/state/demographics/MD")
#
# <ipython-input-6-dc49e9ff5862> in browser_instance(executable_path, headless, download_path)
#      13     chrome_options.add_experimental_option("prefs", {
#      14             "download.default_directory": download_path})
# ---> 15     driver = webdriver.Chrome(executable_path=executable_path, options = chrome_options)
#      16     return driver
#      17
#
# /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      71             service_args=service_args,
#      72             log_path=service_log_path)
# ---> 73         self.service.start()
#      74
#      75         try:
#
# /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/common/service.py in start(self)
#      79         except OSError as err:
#      80             if err.errno == errno.ENOENT:
# ---> 81                 raise WebDriverException(
#      82                     "'%s' executable needs to be in PATH. %s" % (
#      83                         os.path.basename(self.path), self.start_error_message)
#
# WebDriverException: Message: 'MD' executable needs to be in PATH. Please see https://sites.google.com/a/chromium.org/chromedriver/home

# %%
def getter():
    counter = 0
    results = []
    driver.get("https://www.migrationpolicy.org/data/state-profiles/state/demographics/MD")
    next_button = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div/div/div[2]/div/div[1]/div/nav/ul/li[8]/a')))
    table_finder = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="block-system-main"]/div/div/div/div/div[2]')))
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    # print(soup.prettify())
    table = soup.find(class_="panels-flexible-row panels-flexible-row-15-main-row ")
    rows = table.find_all('tr')
    for row in rows[1:]:
      cells = row.find_all('td')
      results.append([cell.text for cell in cells])
#       print(results)

#     next_button.click()
    print('debug')
#     counter = counter + 1
#     print(counter)
#         return(results)


    with open('trisha-results.csv','w') as output_file:
        csvfile = csv.writer(output_file)
        csvfile.writerow(['name', 'organization','date', 'location', 'death','type','na'])
        csvfile.writerows(results)
getter()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c4f6454a508a> in <module>
#      26         csvfile.writerow(['name', 'organization','date', 'location', 'death','type','na'])
#      27         csvfile.writerows(results)
# ---> 28 getter()
#
# <ipython-input-2-c4f6454a508a> in getter()
#       2     counter = 0
#       3     results = []
# ----> 4     driver.get("https://www.migrationpolicy.org/data/state-profiles/state/demographics/MD")
#       5     next_button = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div/div/div[2]/div/div[1]/div/nav/ul/li[8]/a')))
#       6     table_finder = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="block-system-main"]/div/div/div/div/div[2]')))
#
# NameError: name 'driver' is not defined

# %%
df = pd.read_csv('results.csv')
df
# Out:
#                     name         organization                date    location  \
# 0     Abdul Aziz Shaheen                Azadi     August 29, 2008    Pakistan
# 1     Abdul Hakim Shimul              Samakal    February 3, 2017  Bangladesh
# 2       Abdul Haq Baloch       ARY Television  September 29, 2012    Pakistan
# 3    Abdul Qadir Hajizai              WASH TV        May 28, 2012    Pakistan
# 4     Abdul Razzak Johra             Royal TV    November 3, 2008    Pakistan
# ..                   ...                  ...                 ...         ...
# 175        Shahid Soomro               Kawish    October 20, 2002    Pakistan
# 176         Shahid Zehri         Metro 1 News    October 10, 2021    Pakistan
# 177       Shamsur Rahman           Janakantha       July 16, 2000  Bangladesh
# 178           Shan Dahar  Abb Takk Television     January 1, 2014    Pakistan
# 179     Shantanu Bhowmik              Dinraat  September 20, 2017       India
#
#       death                  type  na
# 0    Killed             Crossfire NaN
# 1    Killed  Dangerous Assignment NaN
# 2    Killed                Murder NaN
# 3    Killed                Murder NaN
# 4    Killed                Murder NaN
# ..      ...                   ...  ..
# 175  Killed                Murder NaN
# 176  Killed                Murder NaN
# 177  Killed                Murder NaN
# 178  Killed                Murder NaN
# 179  Killed  Dangerous Assignment NaN
#
# [180 rows x 7 columns]

# %%
def get_names():
    names_list = []
    url_list = []
    base_url = "https://cpj.org/data/people/"
    desc_list = []
    for index, row in df.iterrows():
#         print(row["name"])
#         print('---')
        names_list.append(row["name"])
#     return(names_list)
    for name in names_list:
#             name = name.split(' ','')
        name = name.replace(' ', '-')
        name_w_url = base_url + name
#         print(name_w_url)
#         print('---')
        url_list.append(name_w_url)
    for link in url_list:
#         link = "https://cpj.org/data/people/ahmed-rilwan-abdulla/"
        url = link
        page = requests.get(url)
        soup = requests_get_item(url, "html")
        text = soup.find("article", class_="entry-content")
        desc_list.append(text.text)
    df['desc'] = desc_list
    print(df)
get_names()
# Out:
#                     name         organization                date    location  \
# 0     Abdul Aziz Shaheen                Azadi     August 29, 2008    Pakistan
# 1     Abdul Hakim Shimul              Samakal    February 3, 2017  Bangladesh
# 2       Abdul Haq Baloch       ARY Television  September 29, 2012    Pakistan
# 3    Abdul Qadir Hajizai              WASH TV        May 28, 2012    Pakistan
# 4     Abdul Razzak Johra             Royal TV    November 3, 2008    Pakistan
# ..                   ...                  ...                 ...         ...
# 175        Shahid Soomro               Kawish    October 20, 2002    Pakistan
# 176         Shahid Zehri         Metro 1 News    October 10, 2021    Pakistan
# 177       Shamsur Rahman           Janakantha       July 16, 2000  Bangladesh
# 178           Shan Dahar  Abb Takk Television     January 1, 2014    Pakistan
# 179     Shantanu Bhowmik              Dinraat  September 20, 2017       India
#
#       death                  type  na  \
# 0    Killed             Crossfire NaN
# 1    Killed  Dangerous Assignment NaN
# 2    Killed                Murder NaN
# 3    Killed                Murder NaN
# 4    Killed                Murder NaN
# ..      ...                   ...  ..
# 175  Killed                Murder NaN
# 176  Killed                Murder NaN
# 177  Killed                Murder NaN
# 178  Killed                Murder NaN
# 179  Killed  Dangerous Assignment NaN
#
#                                                   desc
# 0    \n\nA Pakistani airstrike hit the lockup where...
# 1    \nAbdul Hakim Shimul, a reporter for the Bangl...
# 2    \n\n\nUnidentified assailants shot Haq as he w...
# 3    \n\n\nArmed men shot Hajizai, a headmaster of ...
# 4    \n\nSix armed men dragged reporter Johra from ...
# ..                                                 ...
# 175  \nSoomro, a correspondent for the Sindhi-langu...
# 176  \nOn October 10, 2021, Shahid Zehri, a reporte...
# 177  \nRahman, a special correspondent for the Beng...
# 178  \nDahar, a reporter for Abb Takk\nTelevision, ...
# 179  \nShantanu Bhowmik, a reporter for the local B...
#
# [180 rows x 8 columns]

# %%
df.to_csv("final.csv")

# %%
    for year in years:
        url = f"https://www.umpd.umd.edu/stats/arrest_report.cfm?year={year}"
        page = requests.get(url)
        soup = requests_get_item(url, "html")
        ls_rows = soup.find_all("tr")
        ls_rows_noHeaders = ls_rows[1:]
        num_rows = len(ls_rows_noHeaders)//2
        grouped = list(zip(*[iter(ls_rows_noHeaders)]*2))
        for i in grouped:
            subRow1 = i[0].find_all("td")
            subRow2 = i[1].find_all("td")

            arrest_number.append(subRow1[0].text.strip())
            arrested_date_time_charge.append(subRow1[1].text.strip())
            umpd_case_number.append(subRow1[2].text.strip())
            age.append(subRow1[3].text.strip())
            race.append(subRow1[4].text.strip())        
            sex.append(subRow1[5].text.strip())
            description.append(subRow2[0].text.strip())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-d26044b2261b> in <module>
# ----> 1 for year in years:
#       2     url = f"https://www.umpd.umd.edu/stats/arrest_report.cfm?year={year}"
#       3     page = requests.get(url)
#       4     soup = requests_get_item(url, "html")
#       5     ls_rows = soup.find_all("tr")
#
# NameError: name 'years' is not defined
